# %% [markdown]
# **What is Curse Of Dimensionality ?**
#
# Dimensions besically features ko hi kahty hen or muliple features mill kar data point ko represent karty hen jo ka vector ki form mein show hota hai, means jitny ziada features hon gy utny hi dimensions ka vector bany ga.
# ML algorithems mein data ky limited features hi effective hoty hen us sy ziada agar features barhaen gy to us sy performence mein positive effect nahi ho ga magar kae martaba negative impact zaroor ho sakta hai.
# Kae martaba hamary data mein buhat sary features aisy hoty hen extra hoty hen magar unki mojodgi dimentionality ko increase karti hai.
# jisky do nuqsan hoty hen
# - data mein sparse barh jata hai jiski waja sy kuch algorithms achy sy kaam nahi kar paty
# - data mein noise bhi increase hota hai jiski waja sy algorithms achy sy kaam nahi kar paty
#     - like KKN jo ka neighbours ki base per kaam karta hai
# - Ziada dimensions hony ki waja sy Algorithm slow ho jata hai.

# %%
from IPython import display
display.Image("D:\git\jaan_repo\ML_a_to_z\ml_resources/MNIST-dataset.jpg")

# %% [markdown]
# Above image ky (a) section mein daikhen to 28 row and 28 columns hen means 784 blocks(Pixals) hen or har pixal aik feature(dimension) ko represent kar raha hai.
# Magar hamra data maximum 15 x 15 meins 225 pixals mein hai.
# is situation ko deal karny ky 2 method hen.
#
# - **Feature Extaction**
# - **Feature Selection**
